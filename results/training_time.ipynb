# %%
import pickle
import os
import scipy
import numpy as np

# %%
result_path = "/home/jxxiong/A-xjx/deeplde/results/SimpleProblem-200-100-100-10000/method/deca8f6678de4837b3a6663943724e89cee1d922/1714917647-1878054/"
with open(os.path.join(result_path, "stats.dict"), 'rb') as f:
    stats = pickle.load(f)
    
epoch_stats = {k: stats[k][-1] for k in stats.keys() if "train" in k}

epoch_stats['train_time']
# Out:
# 0.39150023460388184

# %%
stats['train_time'].sum() + stats['test_time'].sum() + stats['valid_time'].sum()
# Out:
# 373.04485535621643
